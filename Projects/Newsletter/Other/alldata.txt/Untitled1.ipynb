# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
raw=pd.read_csv('coviddata.csv')

# %%
case=raw['Total Cases']

# %%
state=raw['State/UTs']

# %%
plt.plot(state,case)
plt.show()

# %%
raw
